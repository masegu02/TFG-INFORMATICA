# %%
import pandas as pd
import glob
import os

def procesar_estaciones(file: str) -> pd.DataFrame:
    """
    Procesa un archivo Excel con hojas:
    - 'DATOS'
    - 'UBICACIÓN ESTACIONES'
    - 'ESTACIONES'

    Devuelve un DataFrame en formato largo pivotado
    con series temporales .
    """

    # === 1. Leer hojas necesarias ===
    df_datos = pd.read_excel(file, sheet_name="DATOS", engine="openpyxl")
    df_ubic = pd.read_excel(file, sheet_name="UBICACIÓN ESTACIONES", engine="openpyxl")
    df_est = pd.read_excel(file, sheet_name="ESTACIONES", engine="openpyxl")

    # === 2. Pasar de ancho a largo ===
    df_long = df_datos.melt(
        id_vars=["FDIA", "FEST", "FSEN"],
        value_vars=[f"HOR{i}" for i in range(1, 13)],
        var_name="HORA_REL",
        value_name="VALOR"
    )
    df_long["HORA_REL"] = df_long["HORA_REL"].str.extract(r"(\d+)").astype(int) - 1
    
    # === 3. Calcular hora absoluta  ===
    df_long["HORA_ABS"] = df_long.apply(
        lambda r: r["HORA_REL"] if r["FSEN"].endswith("-") else r["HORA_REL"] + 12,
        axis=1
    )

    # === 4. Extraer sentido y estación ===
    df_long["SENTIDO"] = df_long["FSEN"].str[0].astype(int)
    df_long["EST_ID"] = df_long["FEST"].str.extract(r"(\d+)").astype(int)

    # === 5. Merge con hoja de ubicacion ===
    df_merge = df_long.merge(
        df_ubic,
        left_on=["EST_ID", "SENTIDO"],
        right_on=["Estación", "Sentido"],
        how="left"
    )

    # === 6. Normaliza hoja ESTACIONES y hace merge ===
    df_est = df_est.rename(columns={
        "Nº": "Estación",
        "ESTACIÓN": "Nombre_est",
        "LATITUD": "Lat_base",
        "LONGITUD": "Lon_base"
    })
    df_merge = df_merge.merge(
        df_est[["Estación", "Nombre_est", "Lat_base", "Lon_base"]],
        on="Estación",
        how="left"
    )

    # === 7. Construir nombre de columna ===
    df_merge["COL_NAME"] = df_merge["Nombre"] + "_" + df_merge["Orient."]

    # === 8. Transforma dats de fecha a tipo timestamp ===
    df_merge["FDIA"] = pd.to_datetime(df_merge["FDIA"], dayfirst=True)
    df_merge["timestamp"] = df_merge["FDIA"] + pd.to_timedelta(df_merge["HORA_ABS"], unit="h")

    print(df_merge.head())

    # === 9. Pivotar series temporales ===
    tabla_valores = df_merge.pivot_table(
        index="timestamp",
        columns="COL_NAME",
        values="VALOR"
    ).reset_index()

    # === 10. Redondear a enteros ===
    num_cols = tabla_valores.select_dtypes(include=["float", "float64", "float32"]).columns
    tabla_valores[num_cols] = tabla_valores[num_cols].round(0).astype("Int64")

    return tabla_valores


def unir_estaciones(carpeta: str) -> pd.DataFrame:
    """
    Recorre la carpeta buscando archivos que empiezan con 'DATOS_ESTACIONES',
    concatna los resultados y los ordena por fecha.
    """
    # Buscar todos los archivos que empiezan por DATOS_ESTACIONES
    archivos = sorted(glob.glob(os.path.join(carpeta, "DATOS_ESTACIONES*.xlsx")))

    if not archivos:
        raise FileNotFoundError("No se encontraron archivos 'DATOS_ESTACIONES*.xlsx' en la carpetaindicada.")

    lista_df = []
    for archivo in archivos:
        print(f"Procesando: {os.path.basename(archivo)}")
        df_temp = procesar_estaciones(archivo)
        lista_df.append(df_temp)

    # Concatenar todos los meses
    df_final = pd.concat(lista_df, ignore_index=True)

    # Ordenar por fecha
    df_final = df_final.sort_values("timestamp").reset_index(drop=True)

    return df_final


# === Ejecutar ===
datafinal = unir_estaciones("./DatosEstacionesOctubre2021-Marzo2025")
datafinal.tail()
datafinal.to_excel("DF_FINAL.xlsx", index=False)
# Out:
# Procesando: DATOS_ESTACIONES_ABRIL_2022.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2022-04-01  ES01   1-         0    518         0        1       1       1.0
# 1 2022-04-01  ES01   1=         0   2161        12        1       1       1.0
# 2 2022-04-01  ES01   2-         0    413         0        2       1       1.0
# 3 2022-04-01  ES01   2=         0   1329        12        2       1       1.0
# 4 2022-04-01  ES02   1-         0    285         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2022-04-01 00:00:00
# 1  Paseo de la Castellana_S-N 2022-04-01 12:00:00
# 2  Paseo de la Castellana_N-S 2022-04-01 00:00:00
# 3  Paseo de la Castellana_N-S 2022-04-01 12:00:00
# 4          Calle Princesa_N-S 2022-04-01 00:00:00
# Procesando: DATOS_ESTACIONES_ABRIL_2023.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2023-04-01  ES01   1-         0    819         0        1       1       1.0
# 1 2023-04-01  ES01   1=         0   1223        12        1       1       1.0
# 2 2023-04-01  ES01   2-         0    683         0        2       1       1.0
# 3 2023-04-01  ES01   2=         0   1206        12        2       1       1.0
# 4 2023-04-01  ES02   1-         0    312         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2023-04-01 00:00:00
# 1  Paseo de la Castellana_S-N 2023-04-01 12:00:00
# 2  Paseo de la Castellana_N-S 2023-04-01 00:00:00
# 3  Paseo de la Castellana_N-S 2023-04-01 12:00:00
# 4          Calle Princesa_N-S 2023-04-01 00:00:00
# Procesando: DATOS_ESTACIONES_ABRIL_2024.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2024-04-01  ES01   1-         0    215         0        1       1       1.0
# 1 2024-04-01  ES01   1=         0   1758        12        1       1       1.0
# 2 2024-04-01  ES01   2-         0    290         0        2       1       1.0
# 3 2024-04-01  ES01   2=         0   1050        12        2       1       1.0
# 4 2024-04-01  ES02   1-         0    212         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2024-04-01 00:00:00
# 1  Paseo de la Castellana_S-N 2024-04-01 12:00:00
# 2  Paseo de la Castellana_N-S 2024-04-01 00:00:00
# 3  Paseo de la Castellana_N-S 2024-04-01 12:00:00
# 4          Calle Princesa_N-S 2024-04-01 00:00:00
# Procesando: DATOS_ESTACIONES_AGOSTO_2022.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2022-08-01  ES01   1-         0    183         0        1       1       1.0
# 1 2022-08-01  ES01   1=         0   1220        12        1       1       1.0
# 2 2022-08-01  ES01   2-         0    205         0        2       1       1.0
# 3 2022-08-01  ES01   2=         0    940        12        2       1       1.0
# 4 2022-08-01  ES02   1-         0    226         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2022-08-01 00:00:00
# 1  Paseo de la Castellana_S-N 2022-08-01 12:00:00
# 2  Paseo de la Castellana_N-S 2022-08-01 00:00:00
# 3  Paseo de la Castellana_N-S 2022-08-01 12:00:00
# 4          Calle Princesa_N-S 2022-08-01 00:00:00
# Procesando: DATOS_ESTACIONES_AGOSTO_2023.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2023-08-01  ES01   1-         0    195         0        1       1       1.0
# 1 2023-08-01  ES01   1=         0   1447        12        1       1       1.0
# 2 2023-08-01  ES01   2-         0    149         0        2       1       1.0
# 3 2023-08-01  ES01   2=         0    938        12        2       1       1.0
# 4 2023-08-01  ES02   1-         0    262         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2023-08-01 00:00:00
# 1  Paseo de la Castellana_S-N 2023-08-01 12:00:00
# 2  Paseo de la Castellana_N-S 2023-08-01 00:00:00
# 3  Paseo de la Castellana_N-S 2023-08-01 12:00:00
# 4          Calle Princesa_N-S 2023-08-01 00:00:00
# Procesando: DATOS_ESTACIONES_AGOSTO_2024.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2024-08-01  ES01   1-         0    257         0        1       1       1.0
# 1 2024-08-01  ES01   1=         0   1419        12        1       1       1.0
# 2 2024-08-01  ES01   2-         0    252         0        2       1       1.0
# 3 2024-08-01  ES01   2=         0   1084        12        2       1       1.0
# 4 2024-08-01  ES02   1-         0    302         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2024-08-01 00:00:00
# 1  Paseo de la Castellana_S-N 2024-08-01 12:00:00
# 2  Paseo de la Castellana_N-S 2024-08-01 00:00:00
# 3  Paseo de la Castellana_N-S 2024-08-01 12:00:00
# 4          Calle Princesa_N-S 2024-08-01 00:00:00
# Procesando: DATOS_ESTACIONES_DICIEMBRE_2021.xlsx
# C:\Users\patri_ey1tp50\AppData\Local\Temp\ipykernel_10976\3918316004.py:65: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_merge["FDIA"] = pd.to_datetime(df_merge["FDIA"], dayfirst=True)
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2021-12-01  ES01   1-         0    320         0        1       1       1.0
# 1 2021-12-01  ES01   1=         0   1951        12        1       1       1.0
# 2 2021-12-01  ES01   2-         0    196         0        2       1       1.0
# 3 2021-12-01  ES01   2=         0   1581        12        2       1       1.0
# 4 2021-12-01  ES02   1-         0    288         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2021-12-01 00:00:00
# 1  Paseo de la Castellana_S-N 2021-12-01 12:00:00
# 2  Paseo de la Castellana_N-S 2021-12-01 00:00:00
# 3  Paseo de la Castellana_N-S 2021-12-01 12:00:00
# 4          Calle Princesa_N-S 2021-12-01 00:00:00
# Procesando: DATOS_ESTACIONES_DICIEMBRE_2022.xlsx
# C:\Users\patri_ey1tp50\AppData\Local\Temp\ipykernel_10976\3918316004.py:65: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_merge["FDIA"] = pd.to_datetime(df_merge["FDIA"], dayfirst=True)
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2022-12-01  ES01   1-         0    116         0        1       1       1.0
# 1 2022-12-01  ES01   1=         0   2071        12        1       1       1.0
# 2 2022-12-01  ES01   2-         0    209         0        2       1       1.0
# 3 2022-12-01  ES01   2=         0   1212        12        2       1       1.0
# 4 2022-12-01  ES02   1-         0    222         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2022-12-01 00:00:00
# 1  Paseo de la Castellana_S-N 2022-12-01 12:00:00
# 2  Paseo de la Castellana_N-S 2022-12-01 00:00:00
# 3  Paseo de la Castellana_N-S 2022-12-01 12:00:00
# 4          Calle Princesa_N-S 2022-12-01 00:00:00
# Procesando: DATOS_ESTACIONES_DICIEMBRE_2023.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2023-12-01  ES01   1-         0    638         0        1       1       1.0
# 1 2023-12-01  ES01   1=         0   2289        12        1       1       1.0
# 2 2023-12-01  ES01   2-         0    524         0        2       1       1.0
# 3 2023-12-01  ES01   2=         0   1341        12        2       1       1.0
# 4 2023-12-01  ES02   1-         0    305         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2023-12-01 00:00:00
# 1  Paseo de la Castellana_S-N 2023-12-01 12:00:00
# 2  Paseo de la Castellana_N-S 2023-12-01 00:00:00
# 3  Paseo de la Castellana_N-S 2023-12-01 12:00:00
# 4          Calle Princesa_N-S 2023-12-01 00:00:00
# Procesando: DATOS_ESTACIONES_DICIEMBRE_2024.xlsx
#         FDIA  FEST FSEN  HORA_REL   VALOR  HORA_ABS  SENTIDO  EST_ID  \
# 0 2024-12-01  ES01   1-         0  1053.0         0        1       1
# 1 2024-12-01  ES01   1=         0   923.0        12        1       1
# 2 2024-12-01  ES01   2-         0   773.0         0        2       1
# 3 2024-12-01  ES01   2=         0   866.0        12        2       1
# 4 2024-12-01  ES02   1-         0   392.0         0        1       2
#
#    Estación                  Nombre           Latitud           Longitud  \
# 0       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 1       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 2       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 3       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 4       2.0          Calle Princesa  40,4260679064732  -3,71270896289063
#
#    Sentido Orient.              Nombre_est   Lat_base  Lon_base  \
# 0      1.0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1      1.0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2      2.0     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3      2.0     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4      1.0     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2024-12-01 00:00:00
# 1  Paseo de la Castellana_S-N 2024-12-01 12:00:00
# 2  Paseo de la Castellana_N-S 2024-12-01 00:00:00
# 3  Paseo de la Castellana_N-S 2024-12-01 12:00:00
# 4          Calle Princesa_N-S 2024-12-01 00:00:00
# Procesando: DATOS_ESTACIONES_ENERO_2022.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2022-01-01  ES01   1-         0   1107         0        1       1       1.0
# 1 2022-01-01  ES01   1=         0    613        12        1       1       1.0
# 2 2022-01-01  ES01   2-         0    832         0        2       1       1.0
# 3 2022-01-01  ES01   2=         0    532        12        2       1       1.0
# 4 2022-01-01  ES02   1-         0    200         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2022-01-01 00:00:00
# 1  Paseo de la Castellana_S-N 2022-01-01 12:00:00
# 2  Paseo de la Castellana_N-S 2022-01-01 00:00:00
# 3  Paseo de la Castellana_N-S 2022-01-01 12:00:00
# 4          Calle Princesa_N-S 2022-01-01 00:00:00
# Procesando: DATOS_ESTACIONES_ENERO_2023.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2023-01-01  ES01   1-         0   1308         0        1       1       1.0
# 1 2023-01-01  ES01   1=         0    353        12        1       1       1.0
# 2 2023-01-01  ES01   2-         0    969         0        2       1       1.0
# 3 2023-01-01  ES01   2=         0    592        12        2       1       1.0
# 4 2023-01-01  ES02   1-         0    160         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2023-01-01 00:00:00
# 1  Paseo de la Castellana_S-N 2023-01-01 12:00:00
# 2  Paseo de la Castellana_N-S 2023-01-01 00:00:00
# 3  Paseo de la Castellana_N-S 2023-01-01 12:00:00
# 4          Calle Princesa_N-S 2023-01-01 00:00:00
# Procesando: DATOS_ESTACIONES_ENERO_2024.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2024-01-01  ES01   1-         0   1247         0        1       1       1.0
# 1 2024-01-01  ES01   1=         0    656        12        1       1       1.0
# 2 2024-01-01  ES01   2-         0    867         0        2       1       1.0
# 3 2024-01-01  ES01   2=         0    540        12        2       1       1.0
# 4 2024-01-01  ES02   1-         0    204         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2024-01-01 00:00:00
# 1  Paseo de la Castellana_S-N 2024-01-01 12:00:00
# 2  Paseo de la Castellana_N-S 2024-01-01 00:00:00
# 3  Paseo de la Castellana_N-S 2024-01-01 12:00:00
# 4          Calle Princesa_N-S 2024-01-01 00:00:00
# Procesando: DATOS_ESTACIONES_ENERO_2025.xlsx
#         FDIA  FEST FSEN  HORA_REL   VALOR  HORA_ABS  SENTIDO  EST_ID  \
# 0 2025-01-01  ES01   1-         0  1081.0         0        1       1
# 1 2025-01-01  ES01   1=         0   596.0        12        1       1
# 2 2025-01-01  ES01   2-         0   927.0         0        2       1
# 3 2025-01-01  ES01   2=         0   582.0        12        2       1
# 4 2025-01-01  ES02   1-         0   220.0         0        1       2
#
#    Estación                  Nombre           Latitud           Longitud  \
# 0       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 1       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 2       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 3       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 4       2.0          Calle Princesa  40,4260679064732  -3,71270896289063
#
#    Sentido Orient.              Nombre_est   Lat_base  Lon_base  \
# 0      1.0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1      1.0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2      2.0     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3      2.0     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4      1.0     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2025-01-01 00:00:00
# 1  Paseo de la Castellana_S-N 2025-01-01 12:00:00
# 2  Paseo de la Castellana_N-S 2025-01-01 00:00:00
# 3  Paseo de la Castellana_N-S 2025-01-01 12:00:00
# 4          Calle Princesa_N-S 2025-01-01 00:00:00
# Procesando: DATOS_ESTACIONES_FEBRERO_2022.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2022-02-01  ES01   1-         0    114         0        1       1       1.0
# 1 2022-02-01  ES01   1=         0   2044        12        1       1       1.0
# 2 2022-02-01  ES01   2-         0    135         0        2       1       1.0
# 3 2022-02-01  ES01   2=         0   1211        12        2       1       1.0
# 4 2022-02-01  ES02   1-         0    183         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2022-02-01 00:00:00
# 1  Paseo de la Castellana_S-N 2022-02-01 12:00:00
# 2  Paseo de la Castellana_N-S 2022-02-01 00:00:00
# 3  Paseo de la Castellana_N-S 2022-02-01 12:00:00
# 4          Calle Princesa_N-S 2022-02-01 00:00:00
# Procesando: DATOS_ESTACIONES_FEBRERO_2023.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2023-02-01  ES01   1-         0    240         0        1       1       1.0
# 1 2023-02-01  ES01   1=         0   2106        12        1       1       1.0
# 2 2023-02-01  ES01   2-         0    205         0        2       1       1.0
# 3 2023-02-01  ES01   2=         0   1224        12        2       1       1.0
# 4 2023-02-01  ES02   1-         0    210         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2023-02-01 00:00:00
# 1  Paseo de la Castellana_S-N 2023-02-01 12:00:00
# 2  Paseo de la Castellana_N-S 2023-02-01 00:00:00
# 3  Paseo de la Castellana_N-S 2023-02-01 12:00:00
# 4          Calle Princesa_N-S 2023-02-01 00:00:00
# Procesando: DATOS_ESTACIONES_FEBRERO_2024.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2024-02-01  ES01   1-         0    286         0        1       1       1.0
# 1 2024-02-01  ES01   1=         0   2156        12        1       1       1.0
# 2 2024-02-01  ES01   2-         0    266         0        2       1       1.0
# 3 2024-02-01  ES01   2=         0   1313        12        2       1       1.0
# 4 2024-02-01  ES02   1-         0    244         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2024-02-01 00:00:00
# 1  Paseo de la Castellana_S-N 2024-02-01 12:00:00
# 2  Paseo de la Castellana_N-S 2024-02-01 00:00:00
# 3  Paseo de la Castellana_N-S 2024-02-01 12:00:00
# 4          Calle Princesa_N-S 2024-02-01 00:00:00
# Procesando: DATOS_ESTACIONES_FEBRERO_2025.xlsx
#         FDIA  FEST FSEN  HORA_REL   VALOR  HORA_ABS  SENTIDO  EST_ID  \
# 0 2025-02-01  ES01   1-         0   824.0         0        1       1
# 1 2025-02-01  ES01   1=         0  1272.0        12        1       1
# 2 2025-02-01  ES01   2-         0   669.0         0        2       1
# 3 2025-02-01  ES01   2=         0  1382.0        12        2       1
# 4 2025-02-01  ES02   1-         0   363.0         0        1       2
#
#    Estación                  Nombre           Latitud           Longitud  \
# 0       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 1       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 2       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 3       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 4       2.0          Calle Princesa  40,4260679064732  -3,71270896289063
#
#    Sentido Orient.              Nombre_est   Lat_base  Lon_base  \
# 0      1.0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1      1.0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2      2.0     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3      2.0     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4      1.0     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2025-02-01 00:00:00
# 1  Paseo de la Castellana_S-N 2025-02-01 12:00:00
# 2  Paseo de la Castellana_N-S 2025-02-01 00:00:00
# 3  Paseo de la Castellana_N-S 2025-02-01 12:00:00
# 4          Calle Princesa_N-S 2025-02-01 00:00:00
# Procesando: DATOS_ESTACIONES_JULIO_2022.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2022-07-01  ES01   1-         0    530         0        1       1       1.0
# 1 2022-07-01  ES01   1=         0   2012        12        1       1       1.0
# 2 2022-07-01  ES01   2-         0    518         0        2       1       1.0
# 3 2022-07-01  ES01   2=         0   1266        12        2       1       1.0
# 4 2022-07-01  ES02   1-         0    323         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2022-07-01 00:00:00
# 1  Paseo de la Castellana_S-N 2022-07-01 12:00:00
# 2  Paseo de la Castellana_N-S 2022-07-01 00:00:00
# 3  Paseo de la Castellana_N-S 2022-07-01 12:00:00
# 4          Calle Princesa_N-S 2022-07-01 00:00:00
# Procesando: DATOS_ESTACIONES_JULIO_2023.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2023-07-01  ES01   1-         0    635         0        1       1       1.0
# 1 2023-07-01  ES01   1=         0   2081        12        1       1       1.0
# 2 2023-07-01  ES01   2-         0    409         0        2       1       1.0
# 3 2023-07-01  ES01   2=         0   1230        12        2       1       1.0
# 4 2023-07-01  ES02   1-         0    371         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2023-07-01 00:00:00
# 1  Paseo de la Castellana_S-N 2023-07-01 12:00:00
# 2  Paseo de la Castellana_N-S 2023-07-01 00:00:00
# 3  Paseo de la Castellana_N-S 2023-07-01 12:00:00
# 4          Calle Princesa_N-S 2023-07-01 00:00:00
# Procesando: DATOS_ESTACIONES_JULIO_2024.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2024-07-01  ES01   1-         0    194         0        1       1       1.0
# 1 2024-07-01  ES01   1=         0   1960        12        1       1       1.0
# 2 2024-07-01  ES01   2-         0    201         0        2       1       1.0
# 3 2024-07-01  ES01   2=         0   1253        12        2       1       1.0
# 4 2024-07-01  ES02   1-         0    220         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2024-07-01 00:00:00
# 1  Paseo de la Castellana_S-N 2024-07-01 12:00:00
# 2  Paseo de la Castellana_N-S 2024-07-01 00:00:00
# 3  Paseo de la Castellana_N-S 2024-07-01 12:00:00
# 4          Calle Princesa_N-S 2024-07-01 00:00:00
# Procesando: DATOS_ESTACIONES_JUNIO_2022.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2022-06-01  ES01   1-         0    266         0        1       1       1.0
# 1 2022-06-01  ES01   1=         0   1598        12        1       1       1.0
# 2 2022-06-01  ES01   2-         0    209         0        2       1       1.0
# 3 2022-06-01  ES01   2=         0   1275        12        2       1       1.0
# 4 2022-06-01  ES02   1-         0    198         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2022-06-01 00:00:00
# 1  Paseo de la Castellana_S-N 2022-06-01 12:00:00
# 2  Paseo de la Castellana_N-S 2022-06-01 00:00:00
# 3  Paseo de la Castellana_N-S 2022-06-01 12:00:00
# 4          Calle Princesa_N-S 2022-06-01 00:00:00
# Procesando: DATOS_ESTACIONES_JUNIO_2023.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2023-06-01  ES01   1-         0    317         0        1       1       1.0
# 1 2023-06-01  ES01   1=         0   2302        12        1       1       1.0
# 2 2023-06-01  ES01   2-         0    289         0        2       1       1.0
# 3 2023-06-01  ES01   2=         0   1399        12        2       1       1.0
# 4 2023-06-01  ES02   1-         0    249         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2023-06-01 00:00:00
# 1  Paseo de la Castellana_S-N 2023-06-01 12:00:00
# 2  Paseo de la Castellana_N-S 2023-06-01 00:00:00
# 3  Paseo de la Castellana_N-S 2023-06-01 12:00:00
# 4          Calle Princesa_N-S 2023-06-01 00:00:00
# Procesando: DATOS_ESTACIONES_JUNIO_2024.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2024-06-01  ES01   1-         0    900         0        1       1       1.0
# 1 2024-06-01  ES01   1=         0   1602        12        1       1       1.0
# 2 2024-06-01  ES01   2-         0    762         0        2       1       1.0
# 3 2024-06-01  ES01   2=         0   1264        12        2       1       1.0
# 4 2024-06-01  ES02   1-         0    375         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2024-06-01 00:00:00
# 1  Paseo de la Castellana_S-N 2024-06-01 12:00:00
# 2  Paseo de la Castellana_N-S 2024-06-01 00:00:00
# 3  Paseo de la Castellana_N-S 2024-06-01 12:00:00
# 4          Calle Princesa_N-S 2024-06-01 00:00:00
# Procesando: DATOS_ESTACIONES_MARZO_2022.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2022-03-01  ES01   1-         0    166         0        1       1       1.0
# 1 2022-03-01  ES01   1=         0   2069        12        1       1       1.0
# 2 2022-03-01  ES01   2-         0    145         0        2       1       1.0
# 3 2022-03-01  ES01   2=         0   1286        12        2       1       1.0
# 4 2022-03-01  ES02   1-         0    182         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2022-03-01 00:00:00
# 1  Paseo de la Castellana_S-N 2022-03-01 12:00:00
# 2  Paseo de la Castellana_N-S 2022-03-01 00:00:00
# 3  Paseo de la Castellana_N-S 2022-03-01 12:00:00
# 4          Calle Princesa_N-S 2022-03-01 00:00:00
# Procesando: DATOS_ESTACIONES_MARZO_2023.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2023-03-01  ES01   1-         0    210         0        1       1       1.0
# 1 2023-03-01  ES01   1=         0   2137        12        1       1       1.0
# 2 2023-03-01  ES01   2-         0    188         0        2       1       1.0
# 3 2023-03-01  ES01   2=         0   1185        12        2       1       1.0
# 4 2023-03-01  ES02   1-         0    211         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2023-03-01 00:00:00
# 1  Paseo de la Castellana_S-N 2023-03-01 12:00:00
# 2  Paseo de la Castellana_N-S 2023-03-01 00:00:00
# 3  Paseo de la Castellana_N-S 2023-03-01 12:00:00
# 4          Calle Princesa_N-S 2023-03-01 00:00:00
# Procesando: DATOS_ESTACIONES_MARZO_2024.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2024-03-01  ES01   1-         0    501         0        1       1       1.0
# 1 2024-03-01  ES01   1=         0   2159        12        1       1       1.0
# 2 2024-03-01  ES01   2-         0    437         0        2       1       1.0
# 3 2024-03-01  ES01   2=         0   1281        12        2       1       1.0
# 4 2024-03-01  ES02   1-         0    322         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2024-03-01 00:00:00
# 1  Paseo de la Castellana_S-N 2024-03-01 12:00:00
# 2  Paseo de la Castellana_N-S 2024-03-01 00:00:00
# 3  Paseo de la Castellana_N-S 2024-03-01 12:00:00
# 4          Calle Princesa_N-S 2024-03-01 00:00:00
# Procesando: DATOS_ESTACIONES_MARZO_2025.xlsx
#         FDIA  FEST FSEN  HORA_REL   VALOR  HORA_ABS  SENTIDO  EST_ID  \
# 0 2025-03-01  ES01   1-         0   729.0         0        1       1
# 1 2025-03-01  ES01   1=         0  1297.0        12        1       1
# 2 2025-03-01  ES01   2-         0   638.0         0        2       1
# 3 2025-03-01  ES01   2=         0  1309.0        12        2       1
# 4 2025-03-01  ES02   1-         0   412.0         0        1       2
#
#    Estación                  Nombre           Latitud           Longitud  \
# 0       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 1       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 2       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 3       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 4       2.0          Calle Princesa  40,4260679064732  -3,71270896289063
#
#    Sentido Orient.              Nombre_est   Lat_base  Lon_base  \
# 0      1.0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1      1.0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2      2.0     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3      2.0     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4      1.0     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2025-03-01 00:00:00
# 1  Paseo de la Castellana_S-N 2025-03-01 12:00:00
# 2  Paseo de la Castellana_N-S 2025-03-01 00:00:00
# 3  Paseo de la Castellana_N-S 2025-03-01 12:00:00
# 4          Calle Princesa_N-S 2025-03-01 00:00:00
# Procesando: DATOS_ESTACIONES_MAYO_2022.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2022-05-01  ES01   1-         0    550         0        1       1       1.0
# 1 2022-05-01  ES01   1=         0    619        12        1       1       1.0
# 2 2022-05-01  ES01   2-         0    597         0        2       1       1.0
# 3 2022-05-01  ES01   2=         0    812        12        2       1       1.0
# 4 2022-05-01  ES02   1-         0    286         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# ...
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2022-11-01 00:00:00
# 1  Paseo de la Castellana_S-N 2022-11-01 12:00:00
# 2  Paseo de la Castellana_N-S 2022-11-01 00:00:00
# 3  Paseo de la Castellana_N-S 2022-11-01 12:00:00
# 4          Calle Princesa_N-S 2022-11-01 00:00:00
# Procesando: DATOS_ESTACIONES_NOVIEMBRE_2023.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2023-11-01  ES01   1-         0    941         0        1       1       1.0
# 1 2023-11-01  ES01   1=         0   1294        12        1       1       1.0
# 2 2023-11-01  ES01   2-         0    608         0        2       1       1.0
# 3 2023-11-01  ES01   2=         0    880        12        2       1       1.0
# 4 2023-11-01  ES02   1-         0    382         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2023-11-01 00:00:00
# 1  Paseo de la Castellana_S-N 2023-11-01 12:00:00
# 2  Paseo de la Castellana_N-S 2023-11-01 00:00:00
# 3  Paseo de la Castellana_N-S 2023-11-01 12:00:00
# 4          Calle Princesa_N-S 2023-11-01 00:00:00
# Procesando: DATOS_ESTACIONES_NOVIEMBRE_2024.xlsx
#         FDIA  FEST FSEN  HORA_REL   VALOR  HORA_ABS  SENTIDO  EST_ID  \
# 0 2024-11-01  ES01   1-         0   774.0         0        1       1
# 1 2024-11-01  ES01   1=         0   929.0        12        1       1
# 2 2024-11-01  ES01   2-         0   729.0         0        2       1
# 3 2024-11-01  ES01   2=         0  1100.0        12        2       1
# 4 2024-11-01  ES02   1-         0   347.0         0        1       2
#
#    Estación                  Nombre           Latitud           Longitud  \
# 0       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 1       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 2       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 3       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 4       2.0          Calle Princesa  40,4260679064732  -3,71270896289063
#
#    Sentido Orient.              Nombre_est   Lat_base  Lon_base  \
# 0      1.0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1      1.0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2      2.0     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3      2.0     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4      1.0     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2024-11-01 00:00:00
# 1  Paseo de la Castellana_S-N 2024-11-01 12:00:00
# 2  Paseo de la Castellana_N-S 2024-11-01 00:00:00
# 3  Paseo de la Castellana_N-S 2024-11-01 12:00:00
# 4          Calle Princesa_N-S 2024-11-01 00:00:00
# Procesando: DATOS_ESTACIONES_OCTUBRE_2021.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2021-10-01  ES01   1-         0    502         0        1       1       1.0
# 1 2021-10-01  ES01   1=         0   2233        12        1       1       1.0
# 2 2021-10-01  ES01   2-         0    429         0        2       1       1.0
# 3 2021-10-01  ES01   2=         0   1490        12        2       1       1.0
# 4 2021-10-01  ES02   1-         0    441         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2021-10-01 00:00:00
# 1  Paseo de la Castellana_S-N 2021-10-01 12:00:00
# 2  Paseo de la Castellana_N-S 2021-10-01 00:00:00
# 3  Paseo de la Castellana_N-S 2021-10-01 12:00:00
# 4          Calle Princesa_N-S 2021-10-01 00:00:00
# Procesando: DATOS_ESTACIONES_OCTUBRE_2022.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2022-10-01  ES01   1-         0    940         0        1       1       1.0
# 1 2022-10-01  ES01   1=         0   1496        12        1       1       1.0
# 2 2022-10-01  ES01   2-         0    675         0        2       1       1.0
# 3 2022-10-01  ES01   2=         0   1267        12        2       1       1.0
# 4 2022-10-01  ES02   1-         0    385         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2022-10-01 00:00:00
# 1  Paseo de la Castellana_S-N 2022-10-01 12:00:00
# 2  Paseo de la Castellana_N-S 2022-10-01 00:00:00
# 3  Paseo de la Castellana_N-S 2022-10-01 12:00:00
# 4          Calle Princesa_N-S 2022-10-01 00:00:00
# Procesando: DATOS_ESTACIONES_OCTUBRE_2023.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2023-10-01  ES01   1-         0    674         0        1       1       1.0
# 1 2023-10-01  ES01   1=         0   2293        12        1       1       1.0
# 2 2023-10-01  ES01   2-         0    509         0        2       1       1.0
# 3 2023-10-01  ES01   2=         0   1372        12        2       1       1.0
# 4 2023-10-01  ES02   1-         0    341         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2023-10-01 00:00:00
# 1  Paseo de la Castellana_S-N 2023-10-01 12:00:00
# 2  Paseo de la Castellana_N-S 2023-10-01 00:00:00
# 3  Paseo de la Castellana_N-S 2023-10-01 12:00:00
# 4          Calle Princesa_N-S 2023-10-01 00:00:00
# Procesando: DATOS_ESTACIONES_OCTUBRE_2024.xlsx
#         FDIA  FEST FSEN  HORA_REL   VALOR  HORA_ABS  SENTIDO  EST_ID  \
# 0 2024-10-01  ES01   1-         0   195.0         0        1       1
# 1 2024-10-01  ES01   1=         0  1918.0        12        1       1
# 2 2024-10-01  ES01   2-         0   237.0         0        2       1
# 3 2024-10-01  ES01   2=         0  1216.0        12        2       1
# 4 2024-10-01  ES02   1-         0   261.0         0        1       2
#
#    Estación                  Nombre           Latitud           Longitud  \
# 0       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 1       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 2       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 3       1.0  Paseo de la Castellana  40,4319272588958  -3,68910874956933
# 4       2.0          Calle Princesa  40,4260679064732  -3,71270896289063
#
#    Sentido Orient.              Nombre_est   Lat_base  Lon_base  \
# 0      1.0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1      1.0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2      2.0     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3      2.0     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4      1.0     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2024-10-01 00:00:00
# 1  Paseo de la Castellana_S-N 2024-10-01 12:00:00
# 2  Paseo de la Castellana_N-S 2024-10-01 00:00:00
# 3  Paseo de la Castellana_N-S 2024-10-01 12:00:00
# 4          Calle Princesa_N-S 2024-10-01 00:00:00
# Procesando: DATOS_ESTACIONES_SEPTIEMBRE_2022.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2022-09-01  ES01   1-         0    218         0        1       1       1.0
# 1 2022-09-01  ES01   1=         0   1639        12        1       1       1.0
# 2 2022-09-01  ES01   2-         0    231         0        2       1       1.0
# 3 2022-09-01  ES01   2=         0   1128        12        2       1       1.0
# 4 2022-09-01  ES02   1-         0    184         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2022-09-01 00:00:00
# 1  Paseo de la Castellana_S-N 2022-09-01 12:00:00
# 2  Paseo de la Castellana_N-S 2022-09-01 00:00:00
# 3  Paseo de la Castellana_N-S 2022-09-01 12:00:00
# 4          Calle Princesa_N-S 2022-09-01 00:00:00
# Procesando: DATOS_ESTACIONES_SEPTIEMBRE_2023.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2023-09-01  ES01   1-         0    419         0        1       1       1.0
# 1 2023-09-01  ES01   1=         0   1802        12        1       1       1.0
# 2 2023-09-01  ES01   2-         0    302         0        2       1       1.0
# 3 2023-09-01  ES01   2=         0   1076        12        2       1       1.0
# 4 2023-09-01  ES02   1-         0    247         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2023-09-01 00:00:00
# 1  Paseo de la Castellana_S-N 2023-09-01 12:00:00
# 2  Paseo de la Castellana_N-S 2023-09-01 00:00:00
# 3  Paseo de la Castellana_N-S 2023-09-01 12:00:00
# 4          Calle Princesa_N-S 2023-09-01 00:00:00
# Procesando: DATOS_ESTACIONES_SEPTIEMBRE_2024.xlsx
#         FDIA  FEST FSEN  HORA_REL  VALOR  HORA_ABS  SENTIDO  EST_ID  Estación  \
# 0 2024-09-01  ES01   1-         0    453         0        1       1       1.0
# 1 2024-09-01  ES01   1=         0    553        12        1       1       1.0
# 2 2024-09-01  ES01   2-         0    465         0        2       1       1.0
# 3 2024-09-01  ES01   2=         0    815        12        2       1       1.0
# 4 2024-09-01  ES02   1-         0    271         0        1       2       2.0
#
#                    Nombre           Latitud           Longitud  Sentido  \
# 0  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 1  Paseo de la Castellana  40,4319272588958  -3,68910874956933      1.0
# 2  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 3  Paseo de la Castellana  40,4319272588958  -3,68910874956933      2.0
# 4          Calle Princesa  40,4260679064732  -3,71270896289063      1.0
#
#   Orient.              Nombre_est   Lat_base  Lon_base  \
# 0     S-N  Paseo de la Castellana  40.431927 -3.689109
# 1     S-N  Paseo de la Castellana  40.431927 -3.689109
# 2     N-S  Paseo de la Castellana  40.431927 -3.689109
# 3     N-S  Paseo de la Castellana  40.431927 -3.689109
# 4     N-S          Calle Princesa  40.426068 -3.712709
#
#                      COL_NAME           timestamp
# 0  Paseo de la Castellana_S-N 2024-09-01 00:00:00
# 1  Paseo de la Castellana_S-N 2024-09-01 12:00:00
# 2  Paseo de la Castellana_N-S 2024-09-01 00:00:00
# 3  Paseo de la Castellana_N-S 2024-09-01 12:00:00
# 4          Calle Princesa_N-S 2024-09-01 00:00:00

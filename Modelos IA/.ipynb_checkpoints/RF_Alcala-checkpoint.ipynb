# %%
import pandas as pd

df = pd.read_excel("DF_FINAL.xlsx")

df.head()

calles_base = [
        "Avenida Arcentales",
        "Avenida Menéndez Pelayo",
        "Avenida de la Albufera",
        "Calle Alcalá",
        "Calle Camino de Vinateros",
        "Calle Doctor Esquerdo",
        "Calle José Ortega y Gasset",
        "Calle San Cipriano"
]

calles_este = []

for base in calles_base:
    for col in df.columns:
        if base in col:
            calles_este.append(col)

L = 3  # número de lags

X = pd.DataFrame()

for street in calles_este:
    for lag in range(1, L + 1):
        X[f"{street}_t-{lag}"] = df[street].shift(lag)

# Variables externas reales
X["AEMET_tmed"] = df["AEMET_tmed"]
X["AEMET_prec"] = df["AEMET_prec"]
X["dia_semana"] = df["dia_semana"]
X["festivo"] = df["festivo"]

# Convertir variables categóricas a numéricas
X["dia_semana"] = X["dia_semana"].map({
    "lunes": 0,
    "martes": 1,
    "miércoles": 2,
    "jueves": 3,
    "viernes": 4,
    "sábado": 5,
    "domingo": 6
})

X["festivo"] = X["festivo"].map({
    "no": 0,
    "sí": 1
})


y_col = [col for col in df.columns if "Calle Alcalá" in col][0]
y = df[y_col]

# Limpiar NaNs
X = X.dropna()
y = y.loc[X.index]

# %%
split = int(len(X) * 0.8)

X_train = X.iloc[:split]
X_test  = X.iloc[split:]

y_train = y.iloc[:split]
y_test  = y.iloc[split:]

# %%
X_train
# Out:
#        Avenida Arcentales_E-O_t-1  Avenida Arcentales_E-O_t-2  \
# 3                            12.0                        23.0
# 4                            20.0                        12.0
# 5                            46.0                        20.0
# 6                           122.0                        46.0
# 7                           417.0                       122.0
# ...                           ...                         ...
# 25046                       392.0                       241.0
# 25047                       366.0                       392.0
# 25048                       254.0                       366.0
# 25049                       242.0                       254.0
# 25050                       228.0                       242.0
#
#        Avenida Arcentales_E-O_t-3  Avenida Arcentales_O-E_t-1  \
# 3                            35.0                        24.0
# 4                            23.0                        23.0
# 5                            12.0                        69.0
# 6                            20.0                       299.0
# 7                            46.0                       755.0
# ...                           ...                         ...
# 25046                       246.0                       180.0
# 25047                       241.0                       108.0
# 25048                       392.0                       103.0
# 25049                       366.0                       113.0
# 25050                       254.0                        71.0
#
#        Avenida Arcentales_O-E_t-2  Avenida Arcentales_O-E_t-3  \
# 3                            30.0                        31.0
# 4                            24.0                        30.0
# 5                            23.0                        24.0
# 6                            69.0                        23.0
# 7                           299.0                        69.0
# ...                           ...                         ...
# 25046                       159.0                       179.0
# 25047                       180.0                       159.0
# 25048                       108.0                       180.0
# 25049                       103.0                       108.0
# 25050                       113.0                       103.0
#
#        Avenida Menéndez Pelayo_N-S_t-1  Avenida Menéndez Pelayo_N-S_t-2  \
# 3                                 80.0                             89.0
# 4                                 52.0                             80.0
# 5                                 57.0                             52.0
# 6                                 86.0                             57.0
# 7                                261.0                             86.0
# ...                                ...                              ...
# 25046                            565.0                            496.0
# 25047                            479.0                            565.0
# 25048                            328.0                            479.0
# 25049                            327.0                            328.0
# 25050                            341.0                            327.0
#
#        Avenida Menéndez Pelayo_N-S_t-3  Avenida Menéndez Pelayo_S-N_t-1  ...  \
# 3                                217.0                             51.0  ...
# 4                                 89.0                             37.0  ...
# 5                                 80.0                             45.0  ...
# 6                                 52.0                            216.0  ...
# 7                                 57.0                           1177.0  ...
# ...                                ...                              ...  ...
# 25046                            456.0                            317.0  ...
# 25047                            496.0                            253.0  ...
# 25048                            565.0                            219.0  ...
# 25049                            479.0                            246.0  ...
# 25050                            328.0                            236.0  ...
#
#        Calle San Cipriano_E-O_t-1  Calle San Cipriano_E-O_t-2  \
# 3                            12.0                        20.0
# 4                            22.0                        12.0
# 5                            50.0                        22.0
# 6                           127.0                        50.0
# 7                           189.0                       127.0
# ...                           ...                         ...
# 25046                       151.0                       156.0
# 25047                       129.0                       151.0
# 25048                       122.0                       129.0
# 25049                       162.0                       122.0
# 25050                       136.0                       162.0
#
#        Calle San Cipriano_E-O_t-3  Calle San Cipriano_O-E_t-1  \
# 3                            16.0                        20.0
# 4                            20.0                        14.0
# 5                            12.0                        40.0
# 6                            22.0                       121.0
# 7                            50.0                       177.0
# ...                           ...                         ...
# 25046                       148.0                       236.0
# 25047                       156.0                       205.0
# 25048                       151.0                       162.0
# 25049                       129.0                       193.0
# 25050                       122.0                       201.0
#
#        Calle San Cipriano_O-E_t-2  Calle San Cipriano_O-E_t-3  AEMET_tmed  \
# 3                            19.0                        44.0        19.6
# 4                            20.0                        19.0        19.6
# 5                            14.0                        20.0        19.6
# 6                            40.0                        14.0        19.6
# 7                           121.0                        40.0        19.6
# ...                           ...                         ...         ...
# 25046                       226.0                       253.0        32.2
# 25047                       236.0                       226.0        32.2
# 25048                       205.0                       236.0        32.2
# 25049                       162.0                       205.0        32.2
# 25050                       193.0                       162.0        32.2
#
#        AEMET_prec  dia_semana  festivo
# 3             0.0         4.0      0.0
# 4             0.0         4.0      0.0
# 5             0.0         4.0      0.0
# 6             0.0         4.0      0.0
# 7             0.0         4.0      0.0
# ...           ...         ...      ...
# 25046         0.0         4.0      0.0
# 25047         0.0         4.0      0.0
# 25048         0.0         4.0      0.0
# 25049         0.0         4.0      0.0
# 25050         0.0         4.0      0.0
#
# [15376 rows x 52 columns]

# %%
with pd.ExcelWriter("dataset_RF_Alcala.xlsx") as writer:
    X_train.to_excel(writer, sheet_name="X_train")
    X_test.to_excel(writer, sheet_name="X_test")
    y_train.to_excel(writer, sheet_name="y_train")
    y_test.to_excel(writer, sheet_name="y_test")

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=400,
    max_depth=10,
    min_samples_leaf=20,
    random_state=0,
    n_jobs=-1
)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, min_samples_leaf=20, n_estimators=400,
#                       n_jobs=-1, random_state=0)

# %%
# Predicción en test
y_pred = rf.predict(X_test)

# Predicción próxima hora
X_next = X.iloc[[-1]]
y_next = rf.predict(X_next)

comparacion = pd.DataFrame({
    "Real": y_test,
    "Predicho": y_pred
})

comparacion.to_excel("comparacion_predicciones2.xlsx", index=True)

print("Predicción tráfico en Calle Alcalá (E-O) próxima hora:", y_next[0])
# Out:
# Predicción tráfico en Calle Alcalá (E-O) próxima hora: 998.0431322835316

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Cálculo de métricas
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

def mape(y_true, y_pred, eps=1e-6):
    return np.mean(np.abs((y_true - y_pred) / (y_true + eps))) * 100

mape_val = mape(y_test, y_pred)

print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape_val:.2f} %")
# Out:
# MAE: 74.67
# RMSE: 127.33
# MAPE: 9.69 %

# %%
importances = pd.Series(
    rf.feature_importances_,
    index=X_train.columns
).sort_values(ascending=False)

print(importances.head(10))
# Out:
# Calle Alcalá_E-O_t-1                  0.712481
# Calle Camino de Vinateros_E-O_t-1     0.150751
# Avenida Menéndez Pelayo_S-N_t-1       0.088927
# Calle Alcalá_O-E_t-1                  0.003585
# Calle Alcalá_E-O_t-2                  0.003339
# dia_semana                            0.003305
# Avenida de la Albufera_E-O_t-3        0.002884
# Avenida de la Albufera_O-E_t-1        0.002734
# Calle José Ortega y Gasset_E-O_t-3    0.002538
# Calle Alcalá_E-O_t-3                  0.001938
# dtype: float64

# %%
from sklearn.inspection import permutation_importance

perm = permutation_importance(
    rf,
    X_test,
    y_test,
    n_repeats=10,
    random_state=0,
    n_jobs=-1,
    scoring="neg_mean_absolute_error"
)

perm_df = pd.DataFrame({
    "feature": X_test.columns,
    "importance": perm.importances_mean
}).sort_values("importance", ascending=False)

perm_df.head(10)
# Out:
#                                feature  importance
# 18                Calle Alcalá_E-O_t-1  199.601096
# 24   Calle Camino de Vinateros_E-O_t-1   94.451957
# 15      Avenida de la Albufera_O-E_t-1   15.313836
# 50                          dia_semana   14.939183
# 9      Avenida Menéndez Pelayo_S-N_t-1   11.587937
# 19                Calle Alcalá_E-O_t-2    4.933059
# 14      Avenida de la Albufera_E-O_t-3    4.550354
# 38  Calle José Ortega y Gasset_E-O_t-3    3.381672
# 32       Calle Doctor Esquerdo_N-S_t-3    3.295842
# 20                Calle Alcalá_E-O_t-3    2.756058

# %%
top_k = 8
top_features = perm_df.head(top_k)
top_features
# Out:
#                                feature  importance
# 18                Calle Alcalá_E-O_t-1  199.601096
# 24   Calle Camino de Vinateros_E-O_t-1   94.451957
# 15      Avenida de la Albufera_O-E_t-1   15.313836
# 50                          dia_semana   14.939183
# 9      Avenida Menéndez Pelayo_S-N_t-1   11.587937
# 19                Calle Alcalá_E-O_t-2    4.933059
# 14      Avenida de la Albufera_E-O_t-3    4.550354
# 38  Calle José Ortega y Gasset_E-O_t-3    3.381672

# %%
top_streets = (
    top_features["feature"]
    .str.split("_")
    .str[0]
    .value_counts()
)

top_streets
# Out:
# feature
# Calle Alcalá                  2
# Avenida de la Albufera        2
# Calle Camino de Vinateros     1
# dia                           1
# Avenida Menéndez Pelayo       1
# Calle José Ortega y Gasset    1
# Name: count, dtype: int64

# %%
from pathlib import Path

# Cambiar estos dos valores en cada notebook
modelo = "RF"
calle = "Calle Alcalá"

# Carpeta donde se guardarán las importancias
output_dir = Path("importancias_variables")
output_dir.mkdir(exist_ok=True)

# Guardar todas las variables, no solo el top 10
perm_df_export = perm_df.copy()
perm_df_export["modelo"] = modelo
perm_df_export["calle"] = calle

# Nombre limpio para el archivo
nombre_archivo = f"{modelo}_{calle}".replace(" ", "_").replace("á", "a").replace("é", "e")
nombre_archivo = nombre_archivo.replace("í", "i").replace("ó", "o").replace("ú", "u")

perm_df_export.to_csv(output_dir / f"{nombre_archivo}.csv", index=False)

print(f"Archivo guardado: {output_dir / f'{nombre_archivo}.csv'}")
# Out:
# Archivo guardado: importancias_variables\RF_Calle_Alcala.csv

# %%
calle_objetivo = "Calle Alcalá"   # cámbialo según el notebook
modelo = "RF"                # opcional, para tenerlo identificado

# %%
import pandas as pd
import unicodedata

def normalizar_texto(texto):
    texto = str(texto).lower()
    texto = ''.join(
        c for c in unicodedata.normalize('NFD', texto)
        if unicodedata.category(c) != 'Mn'
    )
    return texto

def clasificar_variable(feature, calle_objetivo):
    f = normalizar_texto(feature)
    calle = normalizar_texto(calle_objetivo)

    # Variables meteorológicas
    if any(palabra in f for palabra in [
        'aemet', 'tmed', 'temp', 'temperatura', 'prec', 'precipitacion',
        'humedad', 'viento', 'presion', 'radiacion'
    ]):
        return 'Variables meteorológicas'

    # Variables de calendario
    if any(palabra in f for palabra in [
        'dia_semana', 'festivo', 'mes', 'hora', 'fin_semana'
    ]):
        return 'Variables de calendario'

    # Retardos de la propia calle
    if calle in f:
        return 'Retardos propia calle'

    # Resto de variables de tráfico
    return 'Retardos otras calles'

# %%
perm_df_aux = perm_df.copy()

perm_df_aux["modelo"] = modelo
perm_df_aux["calle"] = calle_objetivo

perm_df_aux["tipo_variable"] = perm_df_aux["feature"].apply(
    lambda x: clasificar_variable(x, calle_objetivo)
)

perm_df_aux.head(15)
# Out:
#                                feature  importance modelo         calle  \
# 18                Calle Alcalá_E-O_t-1  199.601096     RF  Calle Alcalá
# 24   Calle Camino de Vinateros_E-O_t-1   94.451957     RF  Calle Alcalá
# 15      Avenida de la Albufera_O-E_t-1   15.313836     RF  Calle Alcalá
# 50                          dia_semana   14.939183     RF  Calle Alcalá
# 9      Avenida Menéndez Pelayo_S-N_t-1   11.587937     RF  Calle Alcalá
# 19                Calle Alcalá_E-O_t-2    4.933059     RF  Calle Alcalá
# 14      Avenida de la Albufera_E-O_t-3    4.550354     RF  Calle Alcalá
# 38  Calle José Ortega y Gasset_E-O_t-3    3.381672     RF  Calle Alcalá
# 32       Calle Doctor Esquerdo_N-S_t-3    3.295842     RF  Calle Alcalá
# 20                Calle Alcalá_E-O_t-3    2.756058     RF  Calle Alcalá
# 4           Avenida Arcentales_O-E_t-2    2.597798     RF  Calle Alcalá
# 21                Calle Alcalá_O-E_t-1    2.475254     RF  Calle Alcalá
# 47          Calle San Cipriano_O-E_t-3    0.946601     RF  Calle Alcalá
# 8      Avenida Menéndez Pelayo_N-S_t-3    0.901288     RF  Calle Alcalá
# 2           Avenida Arcentales_E-O_t-3    0.860209     RF  Calle Alcalá
#
#               tipo_variable
# 18    Retardos propia calle
# 24    Retardos otras calles
# 15    Retardos otras calles
# 50  Variables de calendario
# 9     Retardos otras calles
# 19    Retardos propia calle
# 14    Retardos otras calles
# 38    Retardos otras calles
# 32    Retardos otras calles
# 20    Retardos propia calle
# 4     Retardos otras calles
# 21    Retardos propia calle
# 47    Retardos otras calles
# 8     Retardos otras calles
# 2     Retardos otras calles

# %%
perm_df_aux["importance_pos"] = perm_df_aux["importance"].clip(lower=0)

# %%
resumen_tipos = (
    perm_df_aux
    .groupby("tipo_variable")["importance_pos"]
    .sum()
    .reset_index()
)

resumen_tipos["porcentaje"] = (
    100 * resumen_tipos["importance_pos"] / resumen_tipos["importance_pos"].sum()
)

resumen_tipos = resumen_tipos.sort_values("porcentaje", ascending=False)

resumen_tipos
# Out:
#               tipo_variable  importance_pos  porcentaje
# 1     Retardos propia calle      210.654288   56.472010
# 0     Retardos otras calles      147.294264   39.486513
# 2   Variables de calendario       14.939183    4.004883
# 3  Variables meteorológicas        0.136507    0.036595

# %%
meteo_df = perm_df_aux[perm_df_aux["tipo_variable"] == "Variables meteorológicas"] \
    .sort_values("importance", ascending=False)

meteo_df.head(20)
# Out:
#        feature  importance modelo         calle             tipo_variable  \
# 48  AEMET_tmed    0.134141     RF  Calle Alcalá  Variables meteorológicas
# 49  AEMET_prec    0.002366     RF  Calle Alcalá  Variables meteorológicas
#
#     importance_pos
# 48        0.134141
# 49        0.002366

# %%
meteo_total = meteo_df["importance_pos"].sum()
print("Importancia positiva acumulada de meteorología:", meteo_total)
# Out:
# Importancia positiva acumulada de meteorología: 0.13650683849718206

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))

plt.bar(resumen_tipos["tipo_variable"], resumen_tipos["porcentaje"],
        color=['#4C9F70', '#F28E2B', '#8E63CE', '#BDBDBD'],
        edgecolor='black')

plt.ylabel("Porcentaje de importancia acumulada (%)")
plt.xlabel("Tipo de variable")

for i, v in enumerate(resumen_tipos["porcentaje"]):
    plt.text(i, v + 0.5, f"{v:.2f}%", ha='center')

plt.xticks(rotation=20, ha='right')
plt.tight_layout()
plt.show()

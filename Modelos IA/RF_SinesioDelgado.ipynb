# %%
import pandas as pd

df = pd.read_excel("DF_FINAL.xlsx")

df.head()

calles_base = [
    "Avenida de la Ilustración (M-30)",
    "Avenida del Manzanares (M-30)",
    "Avenida de Valladolid",
    "Avenida de Logroño",
    "Avenida Reina Victoria",
    "Calle Bravo Murillo",
    "Calle Cea Bermúdez",
    "Calle Raimundo Fernández Villaverde",
    "Calle San Bernardo",
    "Calle Sinesio Delgado",
    "Francos Rodríguez",
    "Paseo de San Francisco de Sales"
]

calles_noroeste = []

for base in calles_base:
    for col in df.columns:
        if base in col:
            calles_noroeste.append(col)

L = 3  # número de lags

X = pd.DataFrame()

for street in calles_noroeste:
    for lag in range(1, L + 1):
        X[f"{street}_t-{lag}"] = df[street].shift(lag)

# Variables externas reales
X["AEMET_tmed"] = df["AEMET_tmed"]
X["AEMET_prec"] = df["AEMET_prec"]
X["dia_semana"] = df["dia_semana"]
X["festivo"] = df["festivo"]

y_col = [col for col in df.columns if "Calle Sinesio Delgado" in col][0]
y = df[y_col]

# Limpiar NaNs
X = X.dropna()
y = y.loc[X.index]

# %%
split = int(len(X) * 0.8)

X_train = X.iloc[:split]
X_test  = X.iloc[split:]

y_train = y.iloc[:split]
y_test  = y.iloc[split:]

# %%
X_train
# Out:
#        Avenida de la Ilustración (M-30)_E-O_t-1  \
# 3                                         202.0
# 4                                          92.0
# 5                                          61.0
# 6                                          84.0
# 7                                         124.0
# ...                                         ...
# 24955                                    1932.0
# 24956                                    1295.0
# 24957                                     994.0
# 24958                                    1246.0
# 24959                                    1354.0
#
#        Avenida de la Ilustración (M-30)_E-O_t-2  \
# 3                                         282.0
# 4                                         202.0
# 5                                          92.0
# 6                                          61.0
# 7                                          84.0
# ...                                         ...
# 24955                                    1678.0
# 24956                                    1932.0
# 24957                                    1295.0
# 24958                                     994.0
# 24959                                    1246.0
#
#        Avenida de la Ilustración (M-30)_E-O_t-3  \
# 3                                         421.0
# 4                                         282.0
# 5                                         202.0
# 6                                          92.0
# 7                                          61.0
# ...                                         ...
# 24955                                    2011.0
# 24956                                    1678.0
# 24957                                    1932.0
# 24958                                    1295.0
# 24959                                     994.0
#
#        Avenida de la Ilustración (M-30)_O-E_t-1  \
# 3                                         194.0
# 4                                          79.0
# 5                                          63.0
# 6                                          66.0
# 7                                         108.0
# ...                                         ...
# 24955                                    2405.0
# 24956                                    1528.0
# 24957                                    1104.0
# 24958                                    1356.0
# 24959                                    1462.0
#
#        Avenida de la Ilustración (M-30)_O-E_t-2  \
# 3                                         320.0
# 4                                         194.0
# 5                                          79.0
# 6                                          63.0
# 7                                          66.0
# ...                                         ...
# 24955                                    3052.0
# 24956                                    2405.0
# 24957                                    1528.0
# 24958                                    1104.0
# 24959                                    1356.0
#
#        Avenida de la Ilustración (M-30)_O-E_t-3  \
# 3                                         495.0
# 4                                         320.0
# 5                                         194.0
# 6                                          79.0
# 7                                          63.0
# ...                                         ...
# 24955                                    3265.0
# 24956                                    3052.0
# 24957                                    2405.0
# 24958                                    1528.0
# 24959                                    1104.0
#
#        Avenida del Manzanares (M-30)_E-O_t-1  \
# 3                                     1575.0
# 4                                      959.0
# 5                                      771.0
# 6                                      789.0
# 7                                     1417.0
# ...                                      ...
# 24955                                 9999.0
# 24956                                 8463.0
# 24957                                 7046.0
# 24958                                 7264.0
# 24959                                 7311.0
#
#        Avenida del Manzanares (M-30)_E-O_t-2  \
# 3                                     2578.0
# 4                                     1575.0
# 5                                      959.0
# 6                                      771.0
# 7                                      789.0
# ...                                      ...
# 24955                                 9866.0
# 24956                                 9999.0
# 24957                                 8463.0
# 24958                                 7046.0
# 24959                                 7264.0
#
#        Avenida del Manzanares (M-30)_E-O_t-3  \
# 3                                     3177.0
# 4                                     2578.0
# 5                                     1575.0
# 6                                      959.0
# 7                                      771.0
# ...                                      ...
# 24955                                 9999.0
# 24956                                 9866.0
# 24957                                 9999.0
# 24958                                 8463.0
# 24959                                 7046.0
#
#        Avenida del Manzanares (M-30)_N-S_t-1  ...  Francos Rodríguez_E-O_t-1  \
# 3                                      340.0  ...                       40.0
# 4                                      170.0  ...                       43.0
# 5                                      127.0  ...                       35.0
# 6                                      150.0  ...                       40.0
# 7                                      678.0  ...                       56.0
# ...                                      ...  ...                        ...
# 24955                                 4357.0  ...                      142.0
# 24956                                 3394.0  ...                      146.0
# 24957                                 2690.0  ...                      170.0
# 24958                                 3090.0  ...                      149.0
# 24959                                 3440.0  ...                       86.0
#
#        Francos Rodríguez_E-O_t-2  Francos Rodríguez_E-O_t-3  \
# 3                           57.0                       81.0
# 4                           40.0                       57.0
# 5                           43.0                       40.0
# 6                           35.0                       43.0
# 7                           40.0                       35.0
# ...                          ...                        ...
# 24955                      131.0                      108.0
# 24956                      142.0                      131.0
# 24957                      146.0                      142.0
# 24958                      170.0                      146.0
# 24959                      149.0                      170.0
#
#        Francos Rodríguez_O-E_t-1  Francos Rodríguez_O-E_t-2  \
# 3                           32.0                       57.0
# 4                           36.0                       32.0
# 5                           25.0                       36.0
# 6                           31.0                       25.0
# 7                           83.0                       31.0
# ...                          ...                        ...
# 24955                      140.0                      140.0
# 24956                      147.0                      140.0
# 24957                      133.0                      147.0
# 24958                      114.0                      133.0
# 24959                       87.0                      114.0
#
#        Francos Rodríguez_O-E_t-3  AEMET_tmed  AEMET_prec  dia_semana  festivo
# 3                           68.0        19.6         0.0     viernes       no
# 4                           57.0        19.6         0.0     viernes       no
# 5                           32.0        19.6         0.0     viernes       no
# 6                           36.0        19.6         0.0     viernes       no
# 7                           25.0        19.6         0.0     viernes       no
# ...                          ...         ...         ...         ...      ...
# 24955                      126.0        30.4         0.0       lunes       no
# 24956                      140.0        30.4         0.0       lunes       no
# 24957                      140.0        30.4         0.0       lunes       no
# 24958                      147.0        30.4         0.0       lunes       no
# 24959                      133.0        30.4         0.0       lunes       no
#
# [22461 rows x 73 columns]

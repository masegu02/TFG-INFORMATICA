# %%
import pandas as pd
import numpy as np

from xgboost import XGBRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_excel("DF_FINAL.xlsx")

df.head()

calles_base = [
    "Avenida de la Ilustración (M-30)",
    "Avenida del Manzanares (M-30)",
    "Avenida de Valladolid",
    "Avenida de Logroño",
    "Avenida Reina Victoria",
    "Calle Bravo Murillo",
    "Calle Cea Bermúdez",
    "Calle Raimundo Fernández Villaverde",
    "Calle San Bernardo",
    "Calle Sinesio Delgado",
    "Francos Rodríguez",
    "Paseo de San Francisco de Sales"
]

calles_noroeste = []

for base in calles_base:
    for col in df.columns:
        if base in col:
            calles_noroeste.append(col)

L = 3  # número de lags

X = pd.DataFrame()

for street in calles_noroeste:
    for lag in range(1, L + 1):
        X[f"{street}_t-{lag}"] = df[street].shift(lag)

# Variables externas reales
X["AEMET_tmed"] = df["AEMET_tmed"]
X["AEMET_prec"] = df["AEMET_prec"]
X["dia_semana"] = df["dia_semana"]
X["festivo"] = df["festivo"]

# Convertir variables categóricas a numéricas
X["dia_semana"] = X["dia_semana"].map({
    "lunes": 0,
    "martes": 1,
    "miércoles": 2,
    "jueves": 3,
    "viernes": 4,
    "sábado": 5,
    "domingo": 6
})

X["festivo"] = X["festivo"].map({
    "no": 0,
    "sí": 1
})


y_col = [col for col in df.columns if "Calle Sinesio Delgado" in col][0]
y = df[y_col]

# Limpiar NaNs
X = X.dropna()
y = y.loc[X.index]

# %%
# División temporal (80% train, 20% test)
split = int(len(X) * 0.8)

X_train = X.iloc[:split]
X_test = X.iloc[split:]

y_train = y.iloc[:split]
y_test = y.iloc[split:]

print(X_train.shape, X_test.shape)
# Out:
# (15376, 73) (3845, 73)

# %%
with pd.ExcelWriter("dataset_XGBoost_SinesioDelgado.xlsx") as writer:
    X_train.to_excel(writer, sheet_name="X_train")
    X_test.to_excel(writer, sheet_name="X_test")
    y_train.to_excel(writer, sheet_name="y_train")
    y_test.to_excel(writer, sheet_name="y_test")

# %%
from xgboost import XGBRegressor

model = XGBRegressor(
    n_estimators=400,
    max_depth=5,
    learning_rate=0.03,
    subsample=0.9,
    colsample_bytree=0.9,
    gamma=0.1,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.1, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=400,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_test)
# Predicción próxima hora
X_next = X.iloc[[-1]]
y_next = model.predict(X_next)

print("Predicción tráfico en Sinesio Delgado (E-O) próxima hora:", y_next[0])
# Out:
# Predicción tráfico en Sinesio Delgado (E-O) próxima hora: 234.86754

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

mask = y_test != 0
mape = np.mean(np.abs((y_test[mask] - y_pred[mask]) / y_test[mask])) * 100

print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# MAE: 36.09
# RMSE: 53.04
# MAPE: 11.99%

# %%
importances = pd.Series(
    model.feature_importances_,
    index=X_train.columns
).sort_values(ascending=False)

print(importances.head(10))
# Out:
# Avenida Reina Victoria_O-E_t-1                 0.469457
# Avenida de Logroño_O-E_t-1                     0.204933
# Avenida Reina Victoria_E-O_t-1                 0.108285
# Avenida de Logroño_E-O_t-1                     0.073882
# Calle Raimundo Fernández Villaverde_E-O_t-1    0.026647
# Calle Sinesio Delgado_E-O_t-1                  0.013007
# Avenida de Logroño_E-O_t-2                     0.010214
# Calle Bravo Murillo_N-S_t-1                    0.008957
# Calle Sinesio Delgado_O-E_t-1                  0.004765
# Avenida del Manzanares (M-30)_N-S_t-2          0.004753
# dtype: float32

# %%
from sklearn.inspection import permutation_importance

perm = permutation_importance(
    model,
    X_test,
    y_test,
    n_repeats=10,
    random_state=0,
    n_jobs=-1,
    scoring="neg_mean_absolute_error"
)

perm_df = pd.DataFrame({
    "feature": X_test.columns,
    "importance": perm.importances_mean
}).sort_values("importance", ascending=False)

perm_df.head(10)
# Out:
#                                         feature  importance
# 57                Calle Sinesio Delgado_E-O_t-1  108.293321
# 27                   Avenida de Logroño_O-E_t-1   47.488882
# 33               Avenida Reina Victoria_O-E_t-1   46.166038
# 30               Avenida Reina Victoria_E-O_t-1   41.461459
# 24                   Avenida de Logroño_E-O_t-1   27.417205
# 45  Calle Raimundo Fernández Villaverde_E-O_t-1   17.520863
# 58                Calle Sinesio Delgado_E-O_t-2    5.596450
# 60                Calle Sinesio Delgado_O-E_t-1    3.854078
# 25                   Avenida de Logroño_E-O_t-2    3.552514
# 36                  Calle Bravo Murillo_N-S_t-1    3.453044

# %%
top_k = 8
top_features = perm_df.head(top_k)
top_features
# Out:
#                                         feature  importance
# 57                Calle Sinesio Delgado_E-O_t-1  108.293321
# 27                   Avenida de Logroño_O-E_t-1   47.488882
# 33               Avenida Reina Victoria_O-E_t-1   46.166038
# 30               Avenida Reina Victoria_E-O_t-1   41.461459
# 24                   Avenida de Logroño_E-O_t-1   27.417205
# 45  Calle Raimundo Fernández Villaverde_E-O_t-1   17.520863
# 58                Calle Sinesio Delgado_E-O_t-2    5.596450
# 60                Calle Sinesio Delgado_O-E_t-1    3.854078

# %%
top_streets = (
    top_features["feature"]
    .str.split("_")
    .str[0]
    .value_counts()
)
top_streets
# Out:
# feature
# Calle Sinesio Delgado                  3
# Avenida de Logroño                     2
# Avenida Reina Victoria                 2
# Calle Raimundo Fernández Villaverde    1
# Name: count, dtype: int64

# %%
from pathlib import Path

# Cambiar estos dos valores en cada notebook
modelo = "XGBoost"
calle = "Calle Sinesio Delgado"

# Carpeta donde se guardarán las importancias
output_dir = Path("importancias_variables")
output_dir.mkdir(exist_ok=True)

# Guardar todas las variables, no solo el top 10
perm_df_export = perm_df.copy()
perm_df_export["modelo"] = modelo
perm_df_export["calle"] = calle

# Nombre limpio para el archivo
nombre_archivo = f"{modelo}_{calle}".replace(" ", "_").replace("á", "a").replace("é", "e")
nombre_archivo = nombre_archivo.replace("í", "i").replace("ó", "o").replace("ú", "u")

perm_df_export.to_csv(output_dir / f"{nombre_archivo}.csv", index=False)

print(f"Archivo guardado: {output_dir / f'{nombre_archivo}.csv'}")
# Out:
# Archivo guardado: importancias_variables\XGBoost_Calle_Sinesio_Delgado.csv

# %%
calle_objetivo = "Calle Sinesio Delgado"   # cámbialo según el notebook
modelo = "XGBoost"                # opcional, para tenerlo identificado

# %%
import pandas as pd
import unicodedata

def normalizar_texto(texto):
    texto = str(texto).lower()
    texto = ''.join(
        c for c in unicodedata.normalize('NFD', texto)
        if unicodedata.category(c) != 'Mn'
    )
    return texto

def clasificar_variable(feature, calle_objetivo):
    f = normalizar_texto(feature)
    calle = normalizar_texto(calle_objetivo)

    # Variables meteorológicas
    if any(palabra in f for palabra in [
        'aemet', 'tmed', 'temp', 'temperatura', 'prec', 'precipitacion',
        'humedad', 'viento', 'presion', 'radiacion'
    ]):
        return 'Variables meteorológicas'

    # Variables de calendario
    if any(palabra in f for palabra in [
        'dia_semana', 'festivo', 'mes', 'hora', 'fin_semana'
    ]):
        return 'Variables de calendario'

    # Retardos de la propia calle
    if calle in f:
        return 'Retardos propia calle'

    # Resto de variables de tráfico
    return 'Retardos otras calles'

# %%
perm_df_aux = perm_df.copy()

perm_df_aux["modelo"] = modelo
perm_df_aux["calle"] = calle_objetivo

perm_df_aux["tipo_variable"] = perm_df_aux["feature"].apply(
    lambda x: clasificar_variable(x, calle_objetivo)
)

perm_df_aux.head(15)
# Out:
#                                         feature  importance   modelo  \
# 57                Calle Sinesio Delgado_E-O_t-1  108.293321  XGBoost
# 27                   Avenida de Logroño_O-E_t-1   47.488882  XGBoost
# 33               Avenida Reina Victoria_O-E_t-1   46.166038  XGBoost
# 30               Avenida Reina Victoria_E-O_t-1   41.461459  XGBoost
# 24                   Avenida de Logroño_E-O_t-1   27.417205  XGBoost
# 45  Calle Raimundo Fernández Villaverde_E-O_t-1   17.520863  XGBoost
# 58                Calle Sinesio Delgado_E-O_t-2    5.596450  XGBoost
# 60                Calle Sinesio Delgado_O-E_t-1    3.854078  XGBoost
# 25                   Avenida de Logroño_E-O_t-2    3.552514  XGBoost
# 36                  Calle Bravo Murillo_N-S_t-1    3.453044  XGBoost
# 21                Avenida de Valladolid_S-N_t-1    3.055830  XGBoost
# 28                   Avenida de Logroño_O-E_t-2    2.752240  XGBoost
# 6         Avenida del Manzanares (M-30)_E-O_t-1    1.890893  XGBoost
# 10        Avenida del Manzanares (M-30)_N-S_t-2    1.824699  XGBoost
# 26                   Avenida de Logroño_E-O_t-3    1.542103  XGBoost
#
#                     calle          tipo_variable
# 57  Calle Sinesio Delgado  Retardos propia calle
# 27  Calle Sinesio Delgado  Retardos otras calles
# 33  Calle Sinesio Delgado  Retardos otras calles
# 30  Calle Sinesio Delgado  Retardos otras calles
# 24  Calle Sinesio Delgado  Retardos otras calles
# 45  Calle Sinesio Delgado  Retardos otras calles
# 58  Calle Sinesio Delgado  Retardos propia calle
# 60  Calle Sinesio Delgado  Retardos propia calle
# 25  Calle Sinesio Delgado  Retardos otras calles
# 36  Calle Sinesio Delgado  Retardos otras calles
# 21  Calle Sinesio Delgado  Retardos otras calles
# 28  Calle Sinesio Delgado  Retardos otras calles
# 6   Calle Sinesio Delgado  Retardos otras calles
# 10  Calle Sinesio Delgado  Retardos otras calles
# 26  Calle Sinesio Delgado  Retardos otras calles

# %%
perm_df_aux["importance_pos"] = perm_df_aux["importance"].clip(lower=0)

# %%
resumen_tipos = (
    perm_df_aux
    .groupby("tipo_variable")["importance_pos"]
    .sum()
    .reset_index()
)

resumen_tipos["porcentaje"] = (
    100 * resumen_tipos["importance_pos"] / resumen_tipos["importance_pos"].sum()
)

resumen_tipos = resumen_tipos.sort_values("porcentaje", ascending=False)

resumen_tipos
# Out:
#               tipo_variable  importance_pos  porcentaje
# 0     Retardos otras calles      218.283202   64.470403
# 1     Retardos propia calle      119.700687   35.353850
# 3  Variables meteorológicas        0.352113    0.103997
# 2   Variables de calendario        0.242930    0.071750

# %%
meteo_df = perm_df_aux[perm_df_aux["tipo_variable"] == "Variables meteorológicas"] \
    .sort_values("importance", ascending=False)

meteo_df.head(20)
# Out:
#        feature  importance   modelo                  calle  \
# 69  AEMET_tmed    0.343007  XGBoost  Calle Sinesio Delgado
# 70  AEMET_prec    0.009106  XGBoost  Calle Sinesio Delgado
#
#                tipo_variable  importance_pos
# 69  Variables meteorológicas        0.343007
# 70  Variables meteorológicas        0.009106

# %%
meteo_total = meteo_df["importance_pos"].sum()
print("Importancia positiva acumulada de meteorología:", meteo_total)
# Out:
# Importancia positiva acumulada de meteorología: 0.3521125793457031

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))

plt.bar(resumen_tipos["tipo_variable"], resumen_tipos["porcentaje"],
        color=['#4C9F70', '#F28E2B', '#8E63CE', '#BDBDBD'],
        edgecolor='black')

plt.ylabel("Porcentaje de importancia acumulada (%)")
plt.xlabel("Tipo de variable")

for i, v in enumerate(resumen_tipos["porcentaje"]):
    plt.text(i, v + 0.5, f"{v:.2f}%", ha='center')

plt.xticks(rotation=20, ha='right')
plt.tight_layout()
plt.show()

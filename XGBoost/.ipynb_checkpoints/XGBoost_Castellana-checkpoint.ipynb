# %%
import pandas as pd
import numpy as np

from xgboost import XGBRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_excel("DF_FINAL.xlsx")

df.head()

calles_base = [
        "Avenida Cardenal Herrera Oria",
        "Avenida Alfonso XIII",
        "Avenida Brasilia",
        "Avenida General Perón",
        "Calle Arturo Soria",
        "Calle Costa Rica",
        "Calle Génova",
        "Calle Hermanos García Noblejas",
        "Calle José Abascal",
        "Calle López de Hoyos",
        "Calle Príncipe de Vergara",
        "Calle Serrano",
        "Calle Velázquez",
        "Paseo de la Castellana"
]

calles_noreste = []

for base in calles_base:
    for col in df.columns:
        if base in col:
            calles_noreste.append(col)

L = 3  # número de lags

X = pd.DataFrame()

for street in calles_noreste:
    for lag in range(1, L + 1):
        X[f"{street}_t-{lag}"] = df[street].shift(lag)

# Variables externas reales
X["AEMET_tmed"] = df["AEMET_tmed"]
X["AEMET_prec"] = df["AEMET_prec"]
X["dia_semana"] = df["dia_semana"]
X["festivo"] = df["festivo"]

# Convertir variables categóricas a numéricas
X["dia_semana"] = X["dia_semana"].map({
    "lunes": 0,
    "martes": 1,
    "miércoles": 2,
    "jueves": 3,
    "viernes": 4,
    "sábado": 5,
    "domingo": 6
})

X["festivo"] = X["festivo"].map({
    "no": 0,
    "sí": 1
})


y_col = [col for col in df.columns if "Paseo de la Castellana" in col][0]
y = df[y_col]

# Limpiar NaNs
X = X.dropna()
y = y.loc[X.index]

# %%
# División temporal (80% train, 20% test)
split = int(len(X) * 0.8)

X_train = X.iloc[:split]
X_test = X.iloc[split:]

y_train = y.iloc[:split]
y_test = y.iloc[split:]

print(X_train.shape, X_test.shape)
# Out:
# (15376, 79) (3845, 79)

# %%
with pd.ExcelWriter("dataset_XGBoost_Castellana.xlsx") as writer:
    X_train.to_excel(writer, sheet_name="X_train")
    X_test.to_excel(writer, sheet_name="X_test")
    y_train.to_excel(writer, sheet_name="y_train")
    y_test.to_excel(writer, sheet_name="y_test")

# %%
from xgboost import XGBRegressor

model = XGBRegressor(
    n_estimators=400,
    max_depth=5,
    learning_rate=0.03,
    subsample=0.9,
    colsample_bytree=0.9,
    gamma=0.1,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.1, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=400,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_test)
# Predicción próxima hora
X_next = X.iloc[[-1]]
y_next = model.predict(X_next)

print("Predicción tráfico en Castellana (N-S) próxima hora:", y_next[0])
# Out:
# Predicción tráfico en Castellana (N-S) próxima hora: 314.72092

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

mask = y_test != 0
mape = np.mean(np.abs((y_test[mask] - y_pred[mask]) / y_test[mask])) * 100

print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# MAE: 67.22
# RMSE: 96.38
# MAPE: 12.52%

# %%
importances = pd.Series(
    model.feature_importances_,
    index=X_train.columns
).sort_values(ascending=False)

print(importances.head(10))
# Out:
# Calle Hermanos García Noblejas_S-N_t-1    0.590984
# Paseo de la Castellana_N-S_t-1            0.098332
# Calle Costa Rica_E-O_t-1                  0.082921
# Calle Arturo Soria_S-N_t-1                0.067336
# Calle Arturo Soria_N-S_t-3                0.011881
# Calle Velázquez_S-N_t-1                   0.009889
# Calle Príncipe de Vergara_S-N_t-2         0.008778
# Calle Costa Rica_O-E_t-2                  0.006240
# Calle Arturo Soria_N-S_t-1                0.005801
# Calle Arturo Soria_S-N_t-3                0.005362
# dtype: float32

# %%
from sklearn.inspection import permutation_importance

perm = permutation_importance(
    model,
    X_test,
    y_test,
    n_repeats=10,
    random_state=0,
    n_jobs=-1,
    scoring="neg_mean_absolute_error"
)

perm_df = pd.DataFrame({
    "feature": X_test.columns,
    "importance": perm.importances_mean
}).sort_values("importance", ascending=False)

perm_df.head(10)
# Out:
#                                    feature  importance
# 69          Paseo de la Castellana_N-S_t-1  206.242377
# 45  Calle Hermanos García Noblejas_S-N_t-1   86.089635
# 30                Calle Costa Rica_E-O_t-1   33.787185
# 32                Calle Costa Rica_E-O_t-3   13.931817
# 0    Avenida Cardenal Herrera Oria_E-O_t-1    6.288482
# 31                Calle Costa Rica_E-O_t-2    5.505383
# 27              Calle Arturo Soria_S-N_t-1    4.824120
# 70          Paseo de la Castellana_N-S_t-2    3.753771
# 2    Avenida Cardenal Herrera Oria_E-O_t-3    3.359022
# 73          Paseo de la Castellana_S-N_t-2    3.334681

# %%
top_k = 8
top_features = perm_df.head(top_k)
top_features
# Out:
#                                    feature  importance
# 69          Paseo de la Castellana_N-S_t-1  206.242377
# 45  Calle Hermanos García Noblejas_S-N_t-1   86.089635
# 30                Calle Costa Rica_E-O_t-1   33.787185
# 32                Calle Costa Rica_E-O_t-3   13.931817
# 0    Avenida Cardenal Herrera Oria_E-O_t-1    6.288482
# 31                Calle Costa Rica_E-O_t-2    5.505383
# 27              Calle Arturo Soria_S-N_t-1    4.824120
# 70          Paseo de la Castellana_N-S_t-2    3.753771

# %%
top_streets = (
    top_features["feature"]
    .str.split("_")
    .str[0]
    .value_counts()
)
top_streets
# Out:
# feature
# Calle Costa Rica                  3
# Paseo de la Castellana            2
# Calle Hermanos García Noblejas    1
# Avenida Cardenal Herrera Oria     1
# Calle Arturo Soria                1
# Name: count, dtype: int64

# %%
from pathlib import Path

# Cambiar estos dos valores en cada notebook
modelo = "XGBoost"
calle = "Paseo de la Castellana"

# Carpeta donde se guardarán las importancias
output_dir = Path("importancias_variables")
output_dir.mkdir(exist_ok=True)

# Guardar todas las variables, no solo el top 10
perm_df_export = perm_df.copy()
perm_df_export["modelo"] = modelo
perm_df_export["calle"] = calle

# Nombre limpio para el archivo
nombre_archivo = f"{modelo}_{calle}".replace(" ", "_").replace("á", "a").replace("é", "e")
nombre_archivo = nombre_archivo.replace("í", "i").replace("ó", "o").replace("ú", "u")

perm_df_export.to_csv(output_dir / f"{nombre_archivo}.csv", index=False)

print(f"Archivo guardado: {output_dir / f'{nombre_archivo}.csv'}")
# Out:
# Archivo guardado: importancias_variables\XGBoost_Paseo_de_la_Castellana.csv

# %%
calle_objetivo = "Paseo de la Castellana"   # cámbialo según el notebook
modelo = "XGBoost"                # opcional, para tenerlo identificado

# %%
import pandas as pd
import unicodedata

def normalizar_texto(texto):
    texto = str(texto).lower()
    texto = ''.join(
        c for c in unicodedata.normalize('NFD', texto)
        if unicodedata.category(c) != 'Mn'
    )
    return texto

def clasificar_variable(feature, calle_objetivo):
    f = normalizar_texto(feature)
    calle = normalizar_texto(calle_objetivo)

    # Variables meteorológicas
    if any(palabra in f for palabra in [
        'aemet', 'tmed', 'temp', 'temperatura', 'prec', 'precipitacion',
        'humedad', 'viento', 'presion', 'radiacion'
    ]):
        return 'Variables meteorológicas'

    # Variables de calendario
    if any(palabra in f for palabra in [
        'dia_semana', 'festivo', 'mes', 'hora', 'fin_semana'
    ]):
        return 'Variables de calendario'

    # Retardos de la propia calle
    if calle in f:
        return 'Retardos propia calle'

    # Resto de variables de tráfico
    return 'Retardos otras calles'

# %%
perm_df_aux = perm_df.copy()

perm_df_aux["modelo"] = modelo
perm_df_aux["calle"] = calle_objetivo

perm_df_aux["tipo_variable"] = perm_df_aux["feature"].apply(
    lambda x: clasificar_variable(x, calle_objetivo)
)

perm_df_aux.head(15)
# Out:
#                                    feature  importance   modelo  \
# 69          Paseo de la Castellana_N-S_t-1  206.242377  XGBoost
# 45  Calle Hermanos García Noblejas_S-N_t-1   86.089635  XGBoost
# 30                Calle Costa Rica_E-O_t-1   33.787185  XGBoost
# 32                Calle Costa Rica_E-O_t-3   13.931817  XGBoost
# 0    Avenida Cardenal Herrera Oria_E-O_t-1    6.288482  XGBoost
# 31                Calle Costa Rica_E-O_t-2    5.505383  XGBoost
# 27              Calle Arturo Soria_S-N_t-1    4.824120  XGBoost
# 70          Paseo de la Castellana_N-S_t-2    3.753771  XGBoost
# 2    Avenida Cardenal Herrera Oria_E-O_t-3    3.359022  XGBoost
# 73          Paseo de la Castellana_S-N_t-2    3.334681  XGBoost
# 77                              dia_semana    3.272458  XGBoost
# 9             Avenida Alfonso XIII_S-N_t-1    2.966599  XGBoost
# 34                Calle Costa Rica_O-E_t-2    2.621333  XGBoost
# 47  Calle Hermanos García Noblejas_S-N_t-3    2.445123  XGBoost
# 26              Calle Arturo Soria_N-S_t-3    2.302863  XGBoost
#
#                      calle            tipo_variable
# 69  Paseo de la Castellana    Retardos propia calle
# 45  Paseo de la Castellana    Retardos otras calles
# 30  Paseo de la Castellana    Retardos otras calles
# 32  Paseo de la Castellana    Retardos otras calles
# 0   Paseo de la Castellana    Retardos otras calles
# 31  Paseo de la Castellana    Retardos otras calles
# 27  Paseo de la Castellana    Retardos otras calles
# 70  Paseo de la Castellana    Retardos propia calle
# 2   Paseo de la Castellana    Retardos otras calles
# 73  Paseo de la Castellana    Retardos propia calle
# 77  Paseo de la Castellana  Variables de calendario
# 9   Paseo de la Castellana    Retardos otras calles
# 34  Paseo de la Castellana    Retardos otras calles
# 47  Paseo de la Castellana    Retardos otras calles
# 26  Paseo de la Castellana    Retardos otras calles

# %%
perm_df_aux["importance_pos"] = perm_df_aux["importance"].clip(lower=0)

# %%
resumen_tipos = (
    perm_df_aux
    .groupby("tipo_variable")["importance_pos"]
    .sum()
    .reset_index()
)

resumen_tipos["porcentaje"] = (
    100 * resumen_tipos["importance_pos"] / resumen_tipos["importance_pos"].sum()
)

resumen_tipos = resumen_tipos.sort_values("porcentaje", ascending=False)

resumen_tipos
# Out:
#               tipo_variable  importance_pos  porcentaje
# 1     Retardos propia calle      213.511214   52.726817
# 0     Retardos otras calles      188.040258   46.436738
# 2   Variables de calendario        3.272458    0.808137
# 3  Variables meteorológicas        0.114631    0.028308

# %%
meteo_df = perm_df_aux[perm_df_aux["tipo_variable"] == "Variables meteorológicas"] \
    .sort_values("importance", ascending=False)

meteo_df.head(20)
# Out:
#        feature  importance   modelo                   calle  \
# 75  AEMET_tmed    0.114631  XGBoost  Paseo de la Castellana
# 76  AEMET_prec   -0.026476  XGBoost  Paseo de la Castellana
#
#                tipo_variable  importance_pos
# 75  Variables meteorológicas        0.114631
# 76  Variables meteorológicas        0.000000

# %%
meteo_total = meteo_df["importance_pos"].sum()
print("Importancia positiva acumulada de meteorología:", meteo_total)
# Out:
# Importancia positiva acumulada de meteorología: 0.11463088989257812

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))

plt.bar(resumen_tipos["tipo_variable"], resumen_tipos["porcentaje"],
        color=['#4C9F70', '#F28E2B', '#8E63CE', '#BDBDBD'],
        edgecolor='black')

plt.ylabel("Porcentaje de importancia acumulada (%)")
plt.xlabel("Tipo de variable")

for i, v in enumerate(resumen_tipos["porcentaje"]):
    plt.text(i, v + 0.5, f"{v:.2f}%", ha='center')

plt.xticks(rotation=20, ha='right')
plt.tight_layout()
plt.show()

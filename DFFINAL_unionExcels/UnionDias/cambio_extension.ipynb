# %%
import pandas as pd

# Leer el CSV
df = pd.read_csv(
    "DF_FINAL.csv",
    sep=";",              # usa ';' porque es el que habéis estado usando
    low_memory=False
)

# Guardar a Excel
df.to_excel("DF_FINAL.xlsx", index=False)

print("✅ DF_FINAL.xlsx generado correctamente")
# Out:
# ✅ DF_FINAL.xlsx generado correctamente
